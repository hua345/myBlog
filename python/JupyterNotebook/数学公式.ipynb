# %%
import handcalcs.render
import sympy as sp
import numpy as np
from math import sqrt, pi
# 可以使用LaTeX表示数学公式
from IPython.display import Latex
import matplotlib.pyplot as plt

# %%
Latex(r"$\sqrt{x^2+y^2}$")
# Out:
# $\sqrt{x^2+y^2}$

# %%
# %reload_ext sympyprinting
from sympy import *
x, y = symbols("x,y")
sqrt(x**2+y**2)
# Out:
# sqrt(x**2 + y**2)

# %%
plt.title('$y=\sin (x^2)$')
x = np.linspace(-2, 2, 100)
plt.plot(x, np.sin(x ** 2))
plt.show()

# %%
# %%render symbolic
# # 参数symbolic不显示数值过程
# a = 2
# b = 3
# c = 2*a + b/3
# d=sqrt(a/b)+asin(sin(b/c))+(a/b)**(0.5)
# def F(x):
#     return x**2 + 10*x
# Out:
# \[
# \begin{aligned}
# a &= 2 \;
# \\[10pt]
# b &= 3 \;
# \\[10pt]
# c &= 2 \cdot a + \frac{ b }{ 3 } \;
# \\[10pt]
# d &= \sqrt { \frac{ a }{ b } } + \arcsin \left( \sin \left( \frac{ b }{ c } \right) \right) + \left( \frac{ a }{ b } \right) ^{ 0.5 } \;
# \\[10pt]
# \mathrm{def} \;
# \\[10pt]
# \mathrm{return} \;
# \end{aligned}
# \]

# %%
# %%render long
# # 参数short,计算过程显示在一行
# # 参数long,计算过程显示在多行
# d = 2*a + b/3
# Out:
# \[
# \begin{aligned}
# d &= 2 \cdot a + \frac{ b }{ 3 } \\&= 2 \cdot 2 + \frac{ 3 }{ 3 } \\&= 5.0  \\
# \end{aligned}
# \]

# %%
# %%render params
# # 参数params显示数学符号
# x_a = 73
# alpha = 0.9
# beta = 34
# Omega_eta_nu  =3
# Out:
# \[
# \begin{aligned}
# x_{a} &= 73 \;
#  &\alpha &= 0.9 \;
#  &\beta &= 34 \;
# \\[10pt]
#  \Omega_{\eta_{\nu}} &= 3 \;\end{aligned}
# \]

# %%
# %%tex
# # %%tex生成LaTeX
# a = 2 / 3 * sqrt(pi)
# Out:
# \[
# \begin{aligned}
# a &= \frac{ 2 }{ 3 } \cdot \sqrt { \pi }  = \frac{ 2 }{ 3 } \cdot \sqrt { \displaystyle 3.142 } &= \displaystyle 1.182
# \end{aligned}
# \]
